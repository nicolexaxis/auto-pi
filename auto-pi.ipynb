# %%
import pandas as pd
import numpy as np
from plotly import __version__
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
cf.go_offline()
import plotly.graph_objects as go
from plotly.subplots import make_subplots
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv("ford-data2.csv")
df.rename(columns={"Media Cost (Advertiser Currency)": "Media Cost"})
# Out:
#                        Advertiser  \
# 0       {MS} {BU: VN} Ford Linked
# 1       {MS} {BU: VN} Ford Linked
# 2       {MS} {BU: VN} Ford Linked
# 3       {MS} {BU: VN} Ford Linked
# 4       {MS} {BU: VN} Ford Linked
# 5       {MS} {BU: VN} Ford Linked
# 6       {MS} {BU: VN} Ford Linked
# 7       {MS} {BU: VN} Ford Linked
# 8       {MS} {BU: VN} Ford Linked
# 9       {MS} {BU: VN} Ford Linked
# 10      {MS} {BU: VN} Ford Linked
# 11      {MS} {BU: VN} Ford Linked
# 12      {MS} {BU: VN} Ford Linked
# 13      {MS} {BU: VN} Ford Linked
# 14      {MS} {BU: VN} Ford Linked
# 15      {MS} {BU: VN} Ford Linked
# 16      {MS} {BU: VN} Ford Linked
# 17      {MS} {BU: VN} Ford Linked
# 18      {MS} {BU: VN} Ford Linked
# 19      {MS} {BU: VN} Ford Linked
# 20      {MS} {BU: VN} Ford Linked
# 21      {MS} {BU: VN} Ford Linked
# 22      {MS} {BU: VN} Ford Linked
# 23      {MS} {BU: VN} Ford Linked
# 24      {MS} {BU: VN} Ford Linked
# 25      {MS} {BU: VN} Ford Linked
# 26      {MS} {BU: VN} Ford Linked
# 27      {MS} {BU: VN} Ford Linked
# 28      {MS} {BU: VN} Ford Linked
# 29      {MS} {BU: VN} Ford Linked
# ...                           ...
# 108462  {MS} {BU: VN} Ford Linked
# 108463  {MS} {BU: VN} Ford Linked
# 108464  {MS} {BU: VN} Ford Linked
# 108465  {MS} {BU: VN} Ford Linked
# 108466  {MS} {BU: VN} Ford Linked
# 108467  {MS} {BU: VN} Ford Linked
# 108468  {MS} {BU: VN} Ford Linked
# 108469  {MS} {BU: VN} Ford Linked
# 108470  {MS} {BU: VN} Ford Linked
# 108471  {MS} {BU: VN} Ford Linked
# 108472  {MS} {BU: VN} Ford Linked
# 108473  {MS} {BU: VN} Ford Linked
# 108474  {MS} {BU: VN} Ford Linked
# 108475  {MS} {BU: VN} Ford Linked
# 108476  {MS} {BU: VN} Ford Linked
# 108477                        NaN
# 108478               Report Time:
# 108479                Date Range:
# 108480                  Group By:
# 108481                  Group By:
# 108482                  Group By:
# 108483                  Group By:
# 108484                  Group By:
# 108485                  Group By:
# 108486                  Group By:
# 108487                  Group By:
# 108488                  Group By:
# 108489     MRC Accredited Metrics
# 108490     Filter by Campaign ID:
# 108491      Filter by Partner ID:
#
#                                       Advertiser Currency  \
# 0                                                     USD
# 1                                                     USD
# 2                                                     USD
# 3                                                     USD
# 4                                                     USD
# 5                                                     USD
# 6                                                     USD
# 7                                                     USD
# 8                                                     USD
# 9                                                     USD
# 10                                                    USD
# 11                                                    USD
# 12                                                    USD
# 13                                                    USD
# 14                                                    USD
# 15                                                    USD
# 16                                                    USD
# 17                                                    USD
# 18                                                    USD
# 19                                                    USD
# 20                                                    USD
# 21                                                    USD
# 22                                                    USD
# 23                                                    USD
# 24                                                    USD
# 25                                                    USD
# 26                                                    USD
# 27                                                    USD
# 28                                                    USD
# 29                                                    USD
# ...                                                   ...
# 108462                                                USD
# 108463                                                USD
# 108464                                                USD
# 108465                                                USD
# 108466                                                USD
# 108467                                                USD
# 108468                                                USD
# 108469                                                USD
# 108470                                                USD
# 108471                                                USD
# 108472                                                USD
# 108473                                                USD
# 108474                                                USD
# 108475                                                USD
# 108476                                                USD
# 108477                                                NaN
# 108478                               2019/11/14 09:36 GMT
# 108479                           2019/11/07 to 2019/11/13
# 108480                                         Advertiser
# 108481                                Advertiser Currency
# 108482                                    Insertion Order
# 108483                                          Line Item
# 108484                                        Device Type
# 108485                           Floodlight Activity Name
# 108486                                            Browser
# 108487                                   Operating System
# 108488                                            App/URL
# 108489  Impressions(Desktop Video, Mobile Video, Deskt...
# 108490                                            3422227
# 108491                                            3237134
#
#                                           Insertion Order  \
# 0          XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 1          XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 2          XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 3          XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 4          XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 5          XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 6          XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 7          XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 8          XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 9          XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 10         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 11         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 12         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 13         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 14         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 15         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 16         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 17         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 18         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 19         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 20         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 21         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 22         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 23         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 24         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 25         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 26         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 27         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 28         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# 29         XVN19-0192_Everest_Q4_Shopper_Desktop_01136396
# ...                                                   ...
# 108462     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108463     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108464     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108465     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108466     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108467     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108468     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108469     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108470     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108471     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108472     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108473     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108474     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108475     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108476     XVN19-0193_Ecosport_Q4_Shopper_Tablet_01136405
# 108477                                                NaN
# 108478                                                NaN
# 108479                                                NaN
# 108480                                                NaN
# 108481                                                NaN
# 108482                                                NaN
# 108483                                                NaN
# 108484                                                NaN
# 108485                                                NaN
# 108486                                                NaN
# 108487                                                NaN
# 108488                                                NaN
# 108489  Clicks(Desktop Video, Desktop Display, Desktop...
# 108490                                            3422244
# 108491                                                NaN
#
#                                             Line Item Device Type  \
# 0       Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 1       Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 2       Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 3       Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 4       Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 5       Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 6       Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 7       Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 8       Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 9       Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 10      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 11      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 12      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 13      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 14      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 15      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 16      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 17      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 18      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 19      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 20      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 21      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 22      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 23      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 24      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 25      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 26      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 27      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 28      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# 29      Competitor_Conquest_Intender_Desktop_01136396     Desktop
# ...                                               ...         ...
# 108462                 RTG_Researcher_Tablet_01136405      Tablet
# 108463                 RTG_Researcher_Tablet_01136405      Tablet
# 108464                 RTG_Researcher_Tablet_01136405      Tablet
# 108465                 RTG_Researcher_Tablet_01136405      Tablet
# 108466                 RTG_Researcher_Tablet_01136405      Tablet
# 108467                 RTG_Researcher_Tablet_01136405      Tablet
# 108468                 RTG_Researcher_Tablet_01136405      Tablet
# 108469                 RTG_Researcher_Tablet_01136405      Tablet
# 108470                 RTG_Researcher_Tablet_01136405      Tablet
# 108471                 RTG_Researcher_Tablet_01136405      Tablet
# 108472                 RTG_Researcher_Tablet_01136405      Tablet
# 108473                 RTG_Researcher_Tablet_01136405      Tablet
# 108474                 RTG_Researcher_Tablet_01136405      Tablet
# 108475                 RTG_Researcher_Tablet_01136405      Tablet
# 108476                 RTG_Researcher_Tablet_01136405      Tablet
# 108477                                            NaN         NaN
# 108478                                            NaN         NaN
# 108479                                            NaN         NaN
# 108480                                            NaN         NaN
# 108481                                            NaN         NaN
# 108482                                            NaN         NaN
# 108483                                            NaN         NaN
# 108484                                            NaN         NaN
# 108485                                            NaN         NaN
# 108486                                            NaN         NaN
# 108487                                            NaN         NaN
# 108488                                            NaN         NaN
# 108489                                            NaN         NaN
# 108490                                            NaN         NaN
# 108491                                            NaN         NaN
#
#        Floodlight Activity Name Browser Operating System  \
# 0                       Unknown  Chrome        Macintosh
# 1                       Unknown  Chrome        Macintosh
# 2                       Unknown  Chrome        Macintosh
# 3                       Unknown  Chrome        Macintosh
# 4                       Unknown  Chrome        Macintosh
# 5                       Unknown  Chrome        Macintosh
# 6                       Unknown  Chrome        Macintosh
# 7                       Unknown  Chrome        Macintosh
# 8                       Unknown  Chrome        Macintosh
# 9                       Unknown  Chrome        Macintosh
# 10                      Unknown  Chrome        Macintosh
# 11                      Unknown  Chrome        Macintosh
# 12                      Unknown  Chrome        Macintosh
# 13                      Unknown  Chrome        Macintosh
# 14                      Unknown  Chrome        Macintosh
# 15                      Unknown  Chrome        Macintosh
# 16                      Unknown  Chrome        Macintosh
# 17                      Unknown  Chrome        Macintosh
# 18                      Unknown  Chrome        Macintosh
# 19                      Unknown  Chrome        Macintosh
# 20                      Unknown  Chrome        Macintosh
# 21                      Unknown  Chrome        Macintosh
# 22                      Unknown  Chrome        Macintosh
# 23                      Unknown  Chrome        Macintosh
# 24                      Unknown  Chrome        Macintosh
# 25                      Unknown  Chrome        Macintosh
# 26                      Unknown  Chrome        Macintosh
# 27                      Unknown  Chrome        Macintosh
# 28                      Unknown  Chrome        Macintosh
# 29                      Unknown  Chrome        Macintosh
# ...                         ...     ...              ...
# 108462                  Unknown  Safari         iOS 12.4
# 108463                  Unknown  Safari         iOS 12.4
# 108464                  Unknown  Safari         iOS 13.1
# 108465                  Unknown  Safari         iOS 13.1
# 108466                  Unknown  Safari         iOS 13.1
# 108467                  Unknown  Safari         iOS 13.1
# 108468                  Unknown  Safari         iOS 13.1
# 108469                  Unknown  Safari         iOS 13.1
# 108470                  Unknown  Safari         iOS 13.1
# 108471                  Unknown  Safari         iOS 13.1
# 108472                  Unknown  Safari         iOS 13.1
# 108473                  Unknown  Safari         iOS 13.1
# 108474                  Unknown  Safari          iOS 7.0
# 108475                  Unknown  Safari          iOS 8.0
# 108476                  Unknown  Safari          iOS 9.3
# 108477                      NaN     NaN              NaN
# 108478                      NaN     NaN              NaN
# 108479                      NaN     NaN              NaN
# 108480                      NaN     NaN              NaN
# 108481                      NaN     NaN              NaN
# 108482                      NaN     NaN              NaN
# 108483                      NaN     NaN              NaN
# 108484                      NaN     NaN              NaN
# 108485                      NaN     NaN              NaN
# 108486                      NaN     NaN              NaN
# 108487                      NaN     NaN              NaN
# 108488                      NaN     NaN              NaN
# 108489                      NaN     NaN              NaN
# 108490                      NaN     NaN              NaN
# 108491                      NaN     NaN              NaN
#
#                                 App/URL  Impressions  Clicks  \
# 0                           17track.net          2.0     0.0
# 1                            24h.com.vn          9.0     0.0
# 2                              9gag.com          1.0     0.0
# 3                  Low volume inventory          7.0     0.0
# 4                          academia.edu          2.0     0.0
# 5                     addictivetips.com          3.0     0.0
# 6                     adsoftheworld.com          1.0     0.0
# 7                            adweek.com          4.0     0.0
# 8                           allkpop.com          2.0     0.0
# 9                      appletoolbox.com          3.0     0.0
# 10                      arstechnica.com          1.0     0.0
# 11                            astro.com          2.0     0.0
# 12                         autobikes.vn          1.0     0.0
# 13                       babycenter.com          1.0     0.0
# 14                         baeldung.com         19.0     0.0
# 15                        baodatviet.vn          7.0     0.0
# 16                           baomoi.com          2.0     0.0
# 17                              bbc.com          2.0     0.0
# 18                      bbcgoodfood.com          1.0     0.0
# 19                    beginnersbook.com          4.0     0.0
# 20                              bgr.com          5.0     0.0
# 21                        bikeradar.com          1.0     0.0
# 22                        biography.com          2.0     0.0
# 23                         bizsugar.com          1.0     0.0
# 24                           bjpenn.com          1.0     0.0
# 25                        bongda.com.vn         14.0     0.0
# 26                         boredart.com          1.0     0.0
# 27                 brandsoftheworld.com          2.0     0.0
# 28                        brightside.me          1.0     0.0
# 29                       britannica.com          7.0     0.0
# ...                                 ...          ...     ...
# 108462                    vietnamnet.vn          2.0     0.0
# 108463                    vnexpress.net          4.0     0.0
# 108464                       24h.com.vn          4.0     0.0
# 108465  FreeCell Free - iOS (301987699)          1.0     0.0
# 108466                  dailymotion.com          4.0     0.0
# 108467                  kienthuc.net.vn          2.0     0.0
# 108468                      ngoisao.net          2.0     0.0
# 108469                           plo.vn          2.0     0.0
# 108470                  readdrstone.com          1.0     0.0
# 108471                     thanhnien.vn          2.0     0.0
# 108472                    vietnamnet.vn          1.0     0.0
# 108473                    vnexpress.net         11.0     0.0
# 108474                    vnexpress.net          8.0     0.0
# 108475                       24h.com.vn          5.0     0.0
# 108476                huffingtonpost.fr          5.0     0.0
# 108477                              NaN    4995369.0  4261.0
# 108478                              NaN          NaN     NaN
# 108479                              NaN          NaN     NaN
# 108480                              NaN          NaN     NaN
# 108481                              NaN          NaN     NaN
# 108482                              NaN          NaN     NaN
# 108483                              NaN          NaN     NaN
# 108484                              NaN          NaN     NaN
# 108485                              NaN          NaN     NaN
# 108486                              NaN          NaN     NaN
# 108487                              NaN          NaN     NaN
# 108488                              NaN          NaN     NaN
# 108489                              NaN          NaN     NaN
# 108490                              NaN          NaN     NaN
# 108491                              NaN          NaN     NaN
#
#         Total Conversions   Media Cost  \
# 0                     0.0     0.001497
# 1                     0.0     0.009043
# 2                     0.0     0.000675
# 3                     0.0     0.003830
# 4                     0.0     0.001382
# 5                     0.0     0.002562
# 6                     0.0     0.001006
# 7                     0.0     0.004655
# 8                     0.0     0.001598
# 9                     0.0     0.005250
# 10                    0.0     0.000673
# 11                    0.0     0.001397
# 12                    0.0     0.000866
# 13                    0.0     0.000959
# 14                    0.0     0.025500
# 15                    0.0     0.004900
# 16                    0.0     0.001409
# 17                    0.0     0.002884
# 18                    0.0     0.000930
# 19                    0.0     0.002971
# 20                    0.0     0.005420
# 21                    0.0     0.001001
# 22                    0.0     0.001657
# 23                    0.0     0.001345
# 24                    0.0     0.000735
# 25                    0.0     0.011525
# 26                    0.0     0.000760
# 27                    0.0     0.001566
# 28                    0.0     0.000811
# 29                    0.0     0.004302
# ...                   ...          ...
# 108462                0.0     0.002081
# 108463                0.0     0.004024
# 108464                0.0     0.004152
# 108465                0.0     0.000950
# 108466                0.0     0.004280
# 108467                0.0     0.001712
# 108468                0.0     0.002024
# 108469                0.0     0.002140
# 108470                0.0     0.001010
# 108471                0.0     0.002117
# 108472                0.0     0.001070
# 108473                0.0     0.011164
# 108474                0.0     0.008132
# 108475                0.0     0.005085
# 108476                0.0     0.005030
# 108477             6645.0  1649.952526
# 108478                NaN          NaN
# 108479                NaN          NaN
# 108480                NaN          NaN
# 108481                NaN          NaN
# 108482                NaN          NaN
# 108483                NaN          NaN
# 108484                NaN          NaN
# 108485                NaN          NaN
# 108486                NaN          NaN
# 108487                NaN          NaN
# 108488                NaN          NaN
# 108489                NaN          NaN
# 108490                NaN          NaN
# 108491                NaN          NaN
#
#         Custom Bidding: Total impression custom value
# 0                                                0.00
# 1                                                0.00
# 2                                                0.00
# 3                                                0.00
# 4                                                0.00
# 5                                                0.00
# 6                                                0.00
# 7                                                0.00
# 8                                                0.00
# 9                                                0.00
# 10                                               0.00
# 11                                               0.00
# 12                                               0.00
# 13                                               0.00
# 14                                               0.00
# 15                                               0.00
# 16                                               0.00
# 17                                               0.00
# 18                                               0.00
# 19                                               0.00
# 20                                               0.00
# 21                                               0.00
# 22                                               0.00
# 23                                               0.00
# 24                                               0.00
# 25                                               0.00
# 26                                               0.00
# 27                                               0.00
# 28                                               0.00
# 29                                               0.00
# ...                                               ...
# 108462                                           0.00
# 108463                                           0.00
# 108464                                           0.00
# 108465                                           0.00
# 108466                                           0.00
# 108467                                           0.00
# 108468                                           0.00
# 108469                                           0.00
# 108470                                           0.00
# 108471                                           0.00
# 108472                                           0.00
# 108473                                           0.00
# 108474                                           0.00
# 108475                                           0.00
# 108476                                           0.00
# 108477                                        2004.92
# 108478                                            NaN
# 108479                                            NaN
# 108480                                            NaN
# 108481                                            NaN
# 108482                                            NaN
# 108483                                            NaN
# 108484                                            NaN
# 108485                                            NaN
# 108486                                            NaN
# 108487                                            NaN
# 108488                                            NaN
# 108489                                            NaN
# 108490                                            NaN
# 108491                                            NaN
#
# [108492 rows x 14 columns]

# %%
#define extract name plate function

def extract_name_plate(io):
    arr=io.split('_')
    return arr[1]

# %%
#create PI score dictionary for desktop and mobile

pc_score={
'VN_Brand_Gallery':0.5,
'VN_Brand_BP_Start':2.66,
'VN_Brand_Features':0.98,
'VN_Brand_Colorizer':1.26,
'VN_Brand_Offers_Page':0.13,
'VN_Brand_Model_Compare':0.81,
'VN_Brand_Vehicle_Homepage':0.17,
'VN_Brand_Find_Dealer_(LAD)':0.35,
'VN_Brand_Video_Start':1.23,
'VN_Brand_Video_Finish':0.84,
'VN_Brand_Opt_in':5.61,
'VN_Brand_Test_Drive':11.39,
'VN_Brand_BP_Finish':8.09,
'VN_Brand_Brochure_Download':4.94  
}

mobile_score={
'VN_Brand_Gallery':1.69,
'VN_Brand_BP_Start':3.32,
'VN_Brand_Features':3.39,
'VN_Brand_Colorizer':1.31,
'VN_Brand_Offers_Page':0.06,
'VN_Brand_Model_Compare':1.06,
'VN_Brand_Vehicle_Homepage':0.24,
'VN_Brand_Find_Dealer_(LAD)':2.71,
'VN_Brand_Video_Start':0.94,
'VN_Brand_Video_Finish':1.88,
'VN_Brand_Opt_in':7.64,
'VN_Brand_Test_Drive':34.66,
'VN_Brand_BP_Finish':12.91,
'VN_Brand_Brochure_Download':11.37    
}

# %%
#define create tactic column

def add_tactic_column(df):
    df['Tactic']=df.apply(lambda row: 'RTGL Intender' if (('Intender' in str(row['Line Item'])) and ('LAL' in str(row['Line Item'])) and ('RTG' in str(row['Line Item'])))
                          else ('RTGL Readytobuy' if (('Ready' in str(row['Line Item'])) and ('LAL' in str(row['Line Item'])) and ('RTG' in str(row['Line Item'])))
                              else ('RTGL Researcher' if (('Research' in str(row['Line Item'])) and ('LAL' in str(row['Line Item'])) and ('RTG' in str(row['Line Item'])))
                                else ('RTG '+(str(row['Line Item']).split('_')[1]) if 'RTG' in str(row['Line Item'])
                                    else 'Competitor'
                                   )))
                            ,axis=1)
    return df

# %%
#define create strategy column

def add_strategy_column(df):
    df['Strategy']=df.apply(lambda row: 'Lookalike' if 'LAL' in str(row['Line Item'])
                          else ('Prospecting' if 'Competitor' in row['Line Item'] else 'AAM'
                              ),axis=1)
    return df

# %%
#define create PI weight column

def add_weight_column(df):
    df['weight']=df.apply(lambda row: 0 if row['Floodlight Activity Name']=='Unknown'
                          else (pc_score[str(row['Floodlight Activity Name'])] if row['Device Type']=='Desktop' else mobile_score[str(row['Floodlight Activity Name'])]
                              ),axis=1)
    return df

# %%
#define create name plate column

def add_name_plate_column(df):
    df['Name Plate']=df.apply(lambda row: extract_name_plate(str(row['Insertion Order'])),axis=1)
    return df

# %%
#define create browser family column

def add_browser_family_column(df):
    df['browser_family']=df.apply(lambda row: 'Safari' if 'Safari' in str(row['Browser'])
                          else ('Internet Explorer' if 'Internet Explorer' in row['Browser'] else row['Browser']
                              ),axis=1)
    return df

# %%
#define create OS family column

def add_os_family_column(df):
    df['OS Family']=df.apply(lambda row: 'Android' if 'Android' in str(row['Operating System'])
                          else ('iOS' if 'iOS' in row['Operating System'] else ('Windows' if 'Windows' in str(row['Operating System']) else row['Operating System'])
                              ),axis=1)
    return df

# %%
#define create total PI column

def add_pi_column(df):
    df['PI']=df.apply(lambda row: row['weight']*row['Total Conversions'],axis=1)
    return df

# %%
#define create table for device
def pivot_device(df):
    pivot_device=df.pivot_table(index='Device Type',values=['PI','Media Cost'],aggfunc=np.sum)
    pivot_device['CPPI']=pivot_device.apply(lambda row: row['Media Cost'] / row['PI'] if row['PI']!=0 else 0,axis=1)
    pivot_device.sort_values(['Media Cost'],ascending=False)
    return pivot_device

# %%
#define create table for strategy
def pivot_strategy(df):
    pivot_strategy=df.pivot_table(index='Strategy',values=['PI','Media Cost'],aggfunc=np.sum)
    pivot_strategy['CPPI']=pivot_strategy.apply(lambda row: row['Media Cost'] / row['PI'] if row['PI']!=0 else 0,axis=1)
    pivot_strategy=pivot_strategy.sort_values(['Media Cost'],ascending=False)
    return pivot_strategy

# %%
#define create table for tactic
def pivot_tactic(df):
    pivot_tactic=df.pivot_table(index='Tactic',values=['PI','Media Cost'],aggfunc=np.sum)
    pivot_tactic['CPPI']=pivot_tactic.apply(lambda row: row['Media Cost'] / row['PI'] if row['PI']!=0 else 0,axis=1)
    pivot_tactic=pivot_tactic.sort_values(['Media Cost'],ascending=False)
    return pivot_tactic

# %%
#define create table for browser family
def pivot_browser_family(df):
    pivot=df.pivot_table(index='browser_family',values=['PI','Media Cost'],aggfunc=np.sum)
    pivot['CPPI']=pivot.apply(lambda row: row['Media Cost'] / row['PI'] if row['PI']!=0 else 0,axis=1)
    pivot=pivot.sort_values(['Media Cost'],ascending=False)
    return pivot

# %%
#define create table for OS family
def pivot_os_family(df):
    pivot=df.pivot_table(index='OS Family',values=['PI','Media Cost'],aggfunc=np.sum)
    pivot['CPPI']=pivot.apply(lambda row: row['Media Cost'] / row['PI'] if row['PI']!=0 else 0,axis=1)
    pivot=pivot.sort_values(['Media Cost'],ascending=False)
    return pivot

# %%
#define create table for URL
def pivot_url(df):
    pivot=df.pivot_table(index='App/URL',values=['PI','Media Cost'],aggfunc=np.sum)
    pivot['CPPI']=pivot.apply(lambda row: row['Media Cost'] / row['PI'] if row['PI']!=0 else 0,axis=1)
    pivot=pivot.sort_values(['Media Cost'],ascending=False)
    return pivot

# %%
#define create table for tactic-device
def pivot_tactic_device(df):
    pivot_tactic=df.pivot_table(index=['Tactic','Device Type'],values=['PI','Media Cost'],aggfunc=np.sum)
    pivot_tactic['CPPI']=pivot_tactic.apply(lambda row: row['Media Cost'] / row['PI'] if row['PI']!=0 else 0,axis=1)
    pivot_tactic=pivot_tactic.sort_values(['Tactic'],ascending=True)
    return pivot_tactic

# %%
#define create table for strategy-device
def pivot_strategy_device(df):
    pivot_tactic=df.pivot_table(index=['Strategy','Device Type'],values=['PI','Media Cost'],aggfunc=np.sum)
    pivot_tactic['CPPI']=pivot_tactic.apply(lambda row: row['Media Cost'] / row['PI'] if row['PI']!=0 else 0,axis=1)
    pivot_tactic=pivot_tactic.sort_values(['Strategy'],ascending=True)
    return pivot_tactic

# %%
#plot strategy pivot

fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(
    go.Scatter(
        x=strategy_pivot.index,
        y=strategy_pivot['CPPI'],
        name="CPPI",
        line=dict(color='rgba(0, 0, 100, 0.5)', width=1)
    ),secondary_y=True)
fig.add_trace(
    go.Bar(
        x=strategy_pivot.index,
        y=strategy_pivot['Media Cost'],
        name="Media Cost",
        marker=dict(color='lightblue')
    ))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-a7fc1b8fba40> in <module>
#       4 fig.add_trace(
#       5     go.Scatter(
# ----> 6         x=strategy_pivot.index,
#       7         y=strategy_pivot['CPPI'],
#       8         name="CPPI",
#
# NameError: name 'strategy_pivot' is not defined

# %%
#define write to excel function

def write_to_excel(df, df2,df21,df3,df31,df4,df5,df6,sheet,writer):
    df.to_excel(writer,sheet_name=sheet,startrow=0 , startcol=0)   
    df2.to_excel(writer,sheet_name=sheet,startrow=len(df.index)+2, startcol=0) 
    df21.to_excel(writer,sheet_name=sheet,startrow=len(df.index)+2, startcol=5) 
    df3.to_excel(writer,sheet_name=sheet,startrow=len(df21.index)+2+len(df.index)+2, startcol=0)
    df31.to_excel(writer,sheet_name=sheet,startrow=len(df21.index)+2+len(df.index)+2, startcol=5)
    df4.to_excel(writer,sheet_name=sheet,startrow=len(df31.index)+2+len(df21.index)+2+len(df.index)+2, startcol=0)
    df5.to_excel(writer,sheet_name=sheet,startrow=len(df4.index)+2+len(df31.index)+2+len(df21.index)+2+len(df.index)+2, startcol=0)
    df6.to_excel(writer,sheet_name=sheet,startrow=0, startcol=11)

# %%
#define main function

def generate_pi_report():
    df=pd.read_csv("ford-data2.csv")
    df=df.rename(columns={"Media Cost (Advertiser Currency)": "Media Cost"})
    df=df.dropna()
    df=add_name_plate_column(df)
    df=add_strategy_column(df)
    df=add_weight_column(df)
    df=add_pi_column(df)
    df=add_tactic_column(df)
    df=add_browser_family_column(df)
    df=add_os_family_column(df)
    nPlates=df['Name Plate'].unique()
    writer = pd.ExcelWriter('PI report.xlsx', engine='xlsxwriter')
    workbook=writer.book
    money_fmt = workbook.add_format({'num_format': '$#,##0'})
    CPPI_fmt = workbook.add_format({'num_format': '#,##0.00'})
    url_fmt = workbook.add_format({'align': 'right'})
    
    for x in range(nPlates.size):
        worksheet=workbook.add_worksheet(str(nPlates[x]))    
        worksheet.set_zoom(75)
        worksheet.set_column('A:A', 15)
        worksheet.set_column('F:G', 15)
        worksheet.set_column('L2:L10000', 40,url_fmt)
        worksheet.set_column('B:B', 10, money_fmt)
        worksheet.set_column('H:H', 10, money_fmt)
        worksheet.set_column('M:M', 10, money_fmt)
        worksheet.set_column('D:D', 10, CPPI_fmt)
        worksheet.set_column('J:J', 10, CPPI_fmt)
        worksheet.set_column('O:O', 10, CPPI_fmt)
        writer.sheets[str(nPlates[x])]=worksheet
        df1=df[df['Name Plate']==nPlates[x]]
        p1=pivot_device(df1)
        p2=pivot_strategy(df1)
        p21=pivot_strategy_device(df1)
        p3=pivot_tactic(df1)
        p31=pivot_tactic_device(df1)
        p4=pivot_os_family(df1)
        p5=pivot_browser_family(df1)
        p6=pivot_url(df1)
        write_to_excel(p1,p2,p21,p3,p31,p4,p5,p6,str(nPlates[x]),writer) 
    writer.save()

# %%
generate_pi_report()
